# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt

# %%
url = 'https://data.nasdaq.com/api/v3/datatables/ZILLOW/DATA?indicator_id=ZSFH&region_id=394463&api_key=nhngZKzAkdnohAMb46Kx'
response = requests.get(url)
data = response.json()

# %%
url = 'https://data.nasdaq.com/api/v3/datatables/ZILLOW/DATA?indicator_id=ZSFH&region_id=394463&api_key=nhngZKzAkdnohAMb46Kx'
response = requests.get(url)
data = response.json()

if response.status_code == 200:
    # Convert response to JSON format
    data = response.json()
    
    # Extract relevant data
    chicago_data = data['datatable']['data']
    column_names = [column['name'] for column in data['datatable']['columns']]
    
    # Create DataFrame
    chicago_df = pd.DataFrame(chicago_data, columns=column_names)

chicago_df.head()
# Out:
#   indicator_id region_id        date          value
# 0         ZSFH    394463  2024-03-31  328937.600843
# 1         ZSFH    394463  2024-02-29  326275.124782
# 2         ZSFH    394463  2024-01-31  324662.193028
# 3         ZSFH    394463  2023-12-31  323830.973942
# 4         ZSFH    394463  2023-11-30  323073.418225

# %%
chicago_df['date'] = pd.to_datetime(chicago_df['date'])
chicago_df
# Out:
#     indicator_id region_id       date          value
# 0           ZSFH    394463 2024-03-31  328937.600843
# 1           ZSFH    394463 2024-02-29  326275.124782
# 2           ZSFH    394463 2024-01-31  324662.193028
# 3           ZSFH    394463 2023-12-31  323830.973942
# 4           ZSFH    394463 2023-11-30  323073.418225
# ..           ...       ...        ...            ...
# 334         ZSFH    394463 1996-05-31  163116.000000
# 335         ZSFH    394463 1996-04-30  163735.000000
# 336         ZSFH    394463 1996-03-31  164198.000000
# 337         ZSFH    394463 1996-02-29  164604.000000
# 338         ZSFH    394463 1996-01-31  164910.000000
#
# [339 rows x 4 columns]

# %%
chicago_df['date'] = pd.to_datetime(chicago_df['date'])

dates = chicago_df['date']
prices = chicago_df['value']

plt.plot(dates, prices)
plt.title('Chicago House Prices of Single Family Homes')
plt.xlabel('Date')
plt.ylabel('Price ($)')  
plt.tight_layout()

# Display the plot
plt.show()

# %%
url = 'https://data.nasdaq.com/api/v3/datatables/ZILLOW/DATA?indicator_id=ZSFH&region_id=394913&api_key=nhngZKzAkdnohAMb46Kx'
response = requests.get(url)
data = response.json()

if response.status_code == 200:
    # Convert response to JSON format
    data = response.json()
    
    # Extract relevant data
    nyc_data = data['datatable']['data']
    column_names = [column['name'] for column in data['datatable']['columns']]
    
    # Create DataFrame
    nyc_df = pd.DataFrame(nyc_data, columns=column_names)

# %%
nyc_df['date'] = pd.to_datetime(nyc_df['date'])

dates = nyc_df['date']
prices1 = nyc_df['value']

plt.plot(dates, prices1)
plt.title('New York City House Prices of Single Family Homes')
plt.xlabel('Date')
plt.ylabel('Price ($)')  
plt.tight_layout()

# Display the plot
plt.show()

# %%
url = 'https://data.nasdaq.com/api/v3/datatables/ZILLOW/DATA?indicator_id=ZSFH&region_id=753899&api_key=nhngZKzAkdnohAMb46Kx'
response = requests.get(url)
data = response.json()

if response.status_code == 200:
    # Convert response to JSON format
    data = response.json()
    
    # Extract relevant data
    la_data = data['datatable']['data']
    column_names = [column['name'] for column in data['datatable']['columns']]
    
    # Create DataFrame
    la_df = pd.DataFrame(la_data, columns=column_names)

la_df.head()
# Out:
#   indicator_id region_id        date         value
# 0         ZSFH    753899  2024-03-31  1.010073e+06
# 1         ZSFH    753899  2024-02-29  1.011261e+06
# 2         ZSFH    753899  2024-01-31  1.014610e+06
# 3         ZSFH    753899  2023-12-31  1.014526e+06
# 4         ZSFH    753899  2023-11-30  1.008447e+06

# %%
la_df['date'] = pd.to_datetime(la_df['date'])

dates = la_df['date']
prices1 = la_df['value']

plt.plot(dates, prices1)
plt.title('Los Angelos House Prices of Single Family Homes')
plt.xlabel('Date')
plt.ylabel('Price ($)')  
plt.tight_layout()

# Display the plot
plt.show()

# %%
url = 'https://data.nasdaq.com/api/v3/datatables/ZILLOW/DATA?indicator_id=ZSFH&region_id=394514&api_key=nhngZKzAkdnohAMb46Kx'
response = requests.get(url)
data = response.json()

if response.status_code == 200:
    # Convert response to JSON format
    data = response.json()
    
    # Extract relevant data
    dallas_data = data['datatable']['data']
    column_names = [column['name'] for column in data['datatable']['columns']]
    
    # Create DataFrame
    dallas_df = pd.DataFrame(dallas_data, columns=column_names)

dallas_df.head()
# Out:
#   indicator_id region_id        date          value
# 0         ZSFH    394514  2024-03-31  380884.325395
# 1         ZSFH    394514  2024-02-29  379705.246889
# 2         ZSFH    394514  2024-01-31  379211.800735
# 3         ZSFH    394514  2023-12-31  379182.926498
# 4         ZSFH    394514  2023-11-30  379507.799121

# %%
dallas_df['date'] = pd.to_datetime(dallas_df['date'])

dates = dallas_df['date']
prices1 = dallas_df['value']

plt.plot(dates, prices1)
plt.title('Los Angelos House Prices of Single Family Homes')
plt.xlabel('Date')
plt.ylabel('Price ($)')  
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Plot Chicago house prices
plt.plot(chicago_df['date'], chicago_df['value'], label='Chicago')

# Plot New York City house prices
plt.plot(nyc_df['date'], nyc_df['value'], label='New York City')

# Plot Los Angelos house prices
plt.plot(la_df['date'], la_df['value'], label='Los Angelos')

# Plot Dallas house prices
plt.plot(dallas_df['date'], dallas_df['value'], label='Dallas')

# Add titles and labels
plt.title('House Prices of Single Family Homes')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()  # Show legend with labels
plt.tight_layout()

# Display the plot
plt.show()
